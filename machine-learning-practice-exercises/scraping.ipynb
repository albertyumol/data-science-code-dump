# %%
import requests
page = requests.get("https://www.airbnb.com/s/indonesia/experiences?refinement_paths%5B%5D=%2Fexperiences&search_type=search_query&click_referer=t%3ASEE_ALL%7Csid%3A2775803d-ee41-4b56-869e-4d2ddabc4bf9%7Cst%3AEXPERIENCES_FEATURED_ADVENTURES")
page.content
# Out:
# b'<!doctype html>\n<html data-is-hyperloop="true" lang="en" dir="ltr" xmlns:fb="http://ogp.me/ns/fb#"><head><script type="application/javascript">window.sherlock_firstbyte = window.performance && window.performance.timing ? window.performance.timing.responseStart : Number(new Date());</script><script type="application/javascript">!function(){"use strict";var e=730,n="ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789+/";var t=/(?:^| )bev=(.*?)(?:;|$)/,o=!1;function a(){return window.bev=window.bev||function(){if(o||"undefined"==typeof document)return null;o=!0;var e=(document.cookie||"").match(t);return e&&2===e.length?decodeURIComponent(e[1]):null}(),window.bev}!function(){try{if(!a()){var t=function(){for(var e=[],t=15;t>=0;t--)e.push(n[Math.floor(Math.random()*n.length)]);var o=Math.floor(Date.now()/1e3);return"".concat(o,"_").concat(e.join(""))}();o=t,r=document.location.hostname,c=".".concat(r.slice(r.indexOf("airbnb."))),(i=new Date).setDate(i.getDate()+e),document.
# ...

# %%
from bs4 import BeautifulSoup
#soup = BeautifulSoup(page.content, 'html.parser')
soup = BeautifulSoup(page.content, 'html.parser')

# %%
x = soup.find(class_="_rc12wq")
#y = find_all('a').string
print(x)
# Out:
# <div class="_rc12wq"><div itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><meta content="Bali-Gate of Heaven, Swing &amp; Waterfall" itemprop="name"/><meta content="1" itemprop="position"/><meta content="https://www.airbnb.com/experiences/272390?salt=26e18b2a-03df-4095-82ba-b50d4700fc44" itemprop="url"/><div class="_f1jywl" role="presentation"><a aria-busy="false" class="_d69rnt" href="/experiences/272390?location=indonesia&amp;currentTab=experience_tab&amp;federatedSearchId=7e8e26b3-3764-442b-b3d8-4fbae183c3f0&amp;searchId=26e18b2a-03df-4095-82ba-b50d4700fc44&amp;sectionId=6b04a16f-3b4f-454f-a018-158b68164e22&amp;source=p2" target="_blank"><div class="_1yfus1e" role="text"><div><div style="margin-bottom:12px"><div class="_13ky0r6y" style="padding-top:133.3333%;background:none"><div class="_1szwzht"><div class="_kowt4i"><div class="_hxt6u1e" style="padding-top:133.3333%;background-image:url('...');background-size:cover"></div></div></div></div></div></di
# ...

# %%
#le = soup.find('title')
abc = x.find(class_="_1s5t6bf8").string
abc
# Out:
# 'Bali-Gate of Heaven, Swing & Waterfall'

# %%
soup.find_all(class_="_1s5t6bf8")
#le = soup.find("li")
# Out:
# [<div class="_1s5t6bf8" title="Bali-Gate of Heaven, Swing &amp; Waterfall">Bali-Gate of Heaven, Swing &amp; Waterfall</div>,
#  <div class="_1s5t6bf8" title="Traditional Balinese Cooking Class">Traditional Balinese Cooking Class</div>,
#  <div class="_1s5t6bf8" title="Nusa Penida-The Most Wanted Island">Nusa Penida-The Most Wanted Island</div>,
#  <div class="_1s5t6bf8" title="Private Customized_Bali Guided Tours">Private Customized_Bali Guided Tours</div>,
#  <div class="_1s5t6bf8" title="Meditate with a Shaman">Meditate with a Shaman</div>,
#  <div class="_1s5t6bf8" title="Create Your Authentic Coconut Oil-Canggu">Create Your Authentic Coconut Oil-Canggu</div>,
#  <div class="_1s5t6bf8" title="BALI-Fullday Private Customized Tour">BALI-Fullday Private Customized Tour</div>,
#  <div class="_1s5t6bf8" title="Mount Batur Sunrise Trekking - Ubud">Mount Batur Sunrise Trekking - Ubud</div>,
# ...

# %%
le.find(class_="rbCount").string
# Out:
# '(3247)'

# %%
soup.find_all(class_='rbHeader')
# Out:
# [<div class="rbHeader">
#  <span aria-level="3" class="ws_bold" role="heading">
#  				Job Type</span>
#  </div>, <div class="rbHeader">
#  <span aria-level="3" class="ws_bold" role="heading">
#  				Location</span>
#  </div>, <div class="rbHeader">
#  <span aria-level="3" class="ws_bold" role="heading">
#  				Company</span>
#  </div>, <div class="rbHeader">
#  <span aria-level="3" class="ws_bold" role="heading">
#  				Title</span>
#  </div>]

# %%
# Python generators

def factorial():
    pass

result = factorial()

print(next(result))
print(next(result))
print(next(result))
# Out:
# <generator object genMultiplicationTable at 0x7fbd542e2888>
# initialising
# computing  0
# 0
# resuming
# computing  1
# 6

# %%
from twisted.internet import reactor
from multiprocessing import Process, Queue
import scrapy
from scrapy.crawler import CrawlerRunner
from bs4 import BeautifulSoup
from scrapy.utils.project import get_project_settings

settings = get_project_settings()
settings['FEED_FORMAT'] = 'json'
settings['FEED_URI'] = 'result.json'
settings['RANDOMIZE_DOWNLOAD_DELAY'] = True
settings['DOWNLOAD_DELAY'] = 10

import re

class MySpider(scrapy.Spider):
    name = "Indeed"
    def __init__(self): 
        self.count = 0
        self.urls = [
          "https://www.indeed.com.ph/Bpo-Hiring-jobs-in-Makati"
        ]

    def start_requests(self):
        for url in self.urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
        print("processing", response.url)
        soup = BeautifulSoup(response.body, 'html.parser')
        loc = soup.find(id='LOCATION_rbo')
        for le in list(soup.find_all("li")):
            count = le.find(class_="rbCount").string
            location = le.find(class_="rbLabel").string
            yield {"c": count, "l": location}

        print("yielding next url")
        yield scrapy.Request("https://www.indeed.com.ph/jobs?q=Bpo+Hiring&l=Makati&start=10", callback=self.parse)
        self.count += 1

def run_spider():
    def stop_now():
        print('stopping ', reactor)
        reactor.stop()

    def f(q):
        try:
            runner = CrawlerRunner(settings)
            d = runner.crawl(MySpider)
            d.addBoth(lambda _: stop_now())

            reactor.run()
        except Exception as e:
            q.put(e)

    q = Queue()
    p = Process(target=f, args=(q,))
    p.start()
    p.join()

      
run_spider()
# Out:
# processing https://www.indeed.com.ph/Bpo-Hiring-jobs-in-Makati
# stopping  <twisted.internet.epollreactor.EPollReactor object at 0x7fcd8838ad30>

# %%
# !rm result.json
